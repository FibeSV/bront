# %% [markdown]
# Объявления библиотек

# %%
import warnings
warnings.filterwarnings('ignore')
import librosa
import numpy as np
import IPython.display as ipd
import noisereduce as nr
import matplotlib.pyplot as plt
import librosa.display
import python_speech_features
from python_speech_features import mfcc
import sklearn
import os
#для нейронных сетей
import keras
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten,LSTM,TimeDistributed
from keras.layers import Convolution2D, MaxPooling2D,MaxPooling1D,Conv2D, AveragePooling2D
from keras.optimizers import Adam,SGD
from keras.utils import np_utils
from sklearn import metrics
import random
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import optimizers
import datetime
import sklearn
from sklearn.model_selection import train_test_split  
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Класс для работы с данными

# %%
class Bront:
    def __init__(self ,ww,hop, ww_mfc=2048, hop_mfc=512,sr= 22050, n_input=20, n_output=0):
        self.window_wide = ww
        self.window_wide_mfc = ww_mfc
        self.hop = hop
        self.hop_mfc = hop_mfc
        self.n_input = n_input
        self.n_output = n_output
        self.hb_mean = None
        self.sr = sr
        
    def _spectrum(self, data):
        pass
    
    def data_maker(self, path, path_save):
        files = np.array(os.listdir(path))
        for file in files:
            features = np.load(path+file)
            np.save(path_save+file.split('.')[0]+"__data.npy", self._data_ex(features))
            print(path_save+file.split('.')[0]+"__data.npy")    
            
    def _data_ex(self, features):
        rng = range(0, features.shape[1], self.hop)
        dat= np.zeros([len(rng), self.n_input, self.window_wide])
        for i,step in enumerate(rng):
            try:
                dat[i] = features[:,step:step+self.window_wide]
            except:
                pass
        return dat
    
    def _mfcc(self, data):
        m_htk = librosa.feature.mfcc(y=data, sr=self.sr, hop_length=self.hop_mfc,win_length=self.window_wide_mfc, n_mfcc=self.n_input)
        m_htk = sklearn.preprocessing.scale(m_htk, axis=1)
       #mfcc(data,sr,1/sr*(2*self.hop),1/sr*(2*self.hop), numcep = n, nfft = int(sr*self.window_wide) )
        return m_htk
    
    def feature_ex_and_safe(self, path, path_save):
        files = np.array(os.listdir(path))
        for file in files:
            x , sr = librosa.load(path+file)
            np.save(path_save+file.split('.')[0]+"__mfcc.npy",self._mfcc(x[:]))
            print(path_save+file.split('.')[0]+"__mfcc.npy")    
            
    def mark_ex_and_save(self, path, path_save):
        files = np.array(os.listdir(path))
        for file in files:
            start, end = self._get_mark(path+file)
            steps = range(0,end[-1], self.hop*self.hop_mfc)
            target = np.zeros(len(steps))
            k=0
            for i,step in enumerate(steps): 
                if step>end[k]:
                    k+=1
                    if k>=end.shape[0]:
                        break
                if (step<start[k]) and (end[k]<step+self.window_wide*self.hop_mfc): 
                    target[i]=1
            np.save(path_save+file.split('.')[0]+"__target.npy",target)
            print(path_save+file.split('.')[0]+"__target.npy")
            
    def _get_mark(self, path):
        file = open(path)
        raw_mark = file.read(-1)    
        
        start = np.zeros(len(raw_mark.split('\t\n'))-1)
        end = np.zeros(len(raw_mark.split('\t\n'))-1)
        
        for i,mark in enumerate(raw_mark.split('\t\n')):
            if len(mark)==0:
                continue
            try :
                start[i], end[i] = mark.split('\t')
            except:
                try:
                    start[i], end[i] = mark.split('\t')[1].split("\n")[1],mark.split('\t')[2]
                except:
                    pass
        start = np.array(start*self.sr, dtype="int")
        end = np.array(end*self.sr, dtype="int")
        return start, end
            
            
    def _wavelet(self, data):
        pass

# %% [markdown]
# Формирование данных бд

# %%
volonter = Bront(20,1)
path_mark = "data/marks/source/"
path_mark_save = "data/marks/"
volonter.mark_ex_and_save(path_mark, path_mark_save)

path_wav = "data/wav/"
path_features_save = "data/features/"
volonter.feature_ex_and_safe(path_wav , path_features_save)


volonter.data_maker("data/features/","data/dt/")
# Out:
# data/marks/chips__mark__target.npy
# data/marks/clear__mark__target.npy
# data/marks/fast__mark__target.npy
# data/marks/music__mark__target.npy
# data/features/chips__mfcc.npy
# data/features/clear__mfcc.npy
# data/features/fast__mfcc.npy
# data/features/music__mfcc.npy
# data/features/speak__mfcc.npy
# data/features/sport__mfcc.npy
# data/dt/chips__mfcc__data.npy
# data/dt/clear__mfcc__data.npy
# data/dt/fast__mfcc__data.npy
# data/dt/music__mfcc__data.npy
# data/dt/speak__mfcc__data.npy
# data/dt/sport__mfcc__data.npy

# %%
input_shape = (20, 20, 1)
output_shape = 1

model = Sequential()

model.add(Conv2D(5, kernel_size=(5, 5),
                 activation='relu',
                 input_shape=input_shape))
model.add(AveragePooling2D((2, 2)))

# Второй сверточный блок
model.add(Conv2D(16, kernel_size=(7, 7),
                 activation='relu'))
model.add(AveragePooling2D((2, 2)))

# Разворачиваем изображение в вектор
model.add(Flatten())

# Полносвязные слои
#model.add(layers.SimpleRNN(128, activation = 'relu'))
model.add(Dense(units=120, activation='relu'))
model.add(Dense(units=84, activation='relu'))
model.add(Dense(units=output_shape, activation = 'softmax'))
model.summary()
model.compile(optimizer=tf.keras.optimizers.RMSprop(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              metrics=['acc','mse'])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 16, 16, 5)         130
# _________________________________________________________________
# average_pooling2d_13 (Averag (None, 8, 8, 5)           0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 2, 2, 16)          3936
# _________________________________________________________________
# average_pooling2d_14 (Averag (None, 1, 1, 16)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 120)               2040
# _________________________________________________________________
# dense_20 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 16,355
# Trainable params: 16,355
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_target = np.load(path_mark_save + "fast__mark__target.npy")
test_data = np.load("data/dt/fast__mfcc__data.npy")[:test_target.shape[0]].reshape([test_target.shape[0],20, 20,1])
test_target.shape, test_data.shape
# Out:
# ((2669,), (2669, 20, 20, 1))

# %%
model.fit(test_data,test_target, batch_size= 70, epochs= 3)
# Out:
# Epoch 1/3
# 2669/2669 [==============================] - 0s 112us/step - loss: 14.6266 - acc: 0.0461 - mse: 0.9539
# Epoch 2/3
# 2669/2669 [==============================] - 0s 110us/step - loss: 14.6266 - acc: 0.0461 - mse: 0.9539
# Epoch 3/3
# 2669/2669 [==============================] - 0s 110us/step - loss: 14.6266 - acc: 0.0461 - mse: 0.9539

# %% [markdown]
# Временное изображение бд

# %%
import time
tt32= np.load("data/features/clear__mfcc.npy")
mt = np.load(path_mark_save + "clear__mark__target.npy")
whiw = 20
hiphop = 1
for i in range(1000):
    if mt[i]==1:
        print("NICE!!!")
    
    plt.figure(figsize=[20,10])
    librosa.display.specshow(tt32[:,i:i+20])
    plt.show()
    
    time.sleep(2)
    ipd.clear_output()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0328271f1e4f> in <module>
#      12     plt.show()
#      13
# ---> 14     time.sleep(2)
#      15     ipd.clear_output()
#      16
#
# KeyboardInterrupt:

# %% [markdown]
# Попытка обучить кбс на всей выборке

# %%
t = np.load("data/dt/fast__mfcc__data.npy")
targ = np.load("data/marks/fast__mark__target.npy")
T_data = t.reshape([-1,400])[:targ.shape[0]]

# %%
test, train, target_test, target_train = train_test_split(T_data, targ, train_size=0.8,shuffle = True)

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
f1 = np.zeros(len(range(3, 20)))
acc = np.zeros(len(range(3, 20)))
for i,k in enumerate(range(3, 20)):
    model = KNeighborsClassifier(n_neighbors= k).fit(train,target_train)
    predict = model.predict(test)
    f1[i], acc[i] =f1_score(predict,target_test), accuracy_score(predict,target_test)

model = KNeighborsClassifier(n_neighbors= 3+f1.argmax()).fit(train,target_train)
predict = model.predict(test)
3+f1.argmax(),f1.max(), acc.max()
# Out:
# Wall time: 21.6 s
# (3, 0.4785276073619632, 0.9601873536299765)

# %%
target_test[target_test== True] == predict[target_test== True]
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False,  True, False, False, False, False, False, False,  True,
#        False, False,  True, False, False, False,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False])

# %%
predict.sum(), target_test.sum()
# Out:
# (20.0, 46.0)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,10])
plt.plot( range(3,20), acc, label="accuracy")
plt.plot(range(3,20), f1,  label="f1")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('Колличество соседей', fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
f1 = np.zeros(len(range(10, 200, 10)))
acc = np.zeros(len(range(10, 200, 10)))
for i,k in enumerate(range(10, 200, 10)):
    model = RandomForestClassifier(k).fit(train,target_train)
    predict = model.predict(test)
    f1[i], acc[i] =f1_score(predict,target_test), accuracy_score(predict,target_test)
10+10*f1.argmax(),f1.max(), acc.max()
# Out:
# Wall time: 26.3 s
# (10, 0.0, 0.971604938271605)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,10])
plt.plot( range(10, 200, 10), acc, label="accuracy")
plt.plot(range(10, 200, 10), f1,  label="f1")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('Колличество решающих деревьев', fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()

# %%
test = Bront(5,1)
files = np.array(os.listdir("data/wav/"))
files = np.delete(files,0)
plt.figure(figsize= [35,25])
st = 500000
en = 700000
time = np.arange(0,(en-st))/22050
for i,file in enumerate(files):
    ax1 =plt.subplot(10, 1, 2*i+1)
    x , sr = librosa.load('data/wav/'+file)
    plt.plot(time,x[st:en])
    plt.xlim(0, time[-1])
    plt.xticks(time[::int(22050/4)])
   # plt.setp(ax1.get_xticklabels(), fontsize=6)
    plt.title(file)
    plt.subplot(10, 1, 2*(i+1))
    librosa.display.specshow(test._mfcc(x[st:en]), x_axis='time')
    
    plt.title(file)

# %%
input_shape = (20, 24, 1)
output_shape = 1
model = Sequential()
model.add(Conv2D(5, kernel_size=(4, 4),
                 activation='relu',
                 input_shape=input_shape))
model.add(AveragePooling2D((2, 2)))
# Второй сверточный блок
model.add(Conv2D(16, kernel_size=(3, 3),
                 activation='relu'))
model.add(AveragePooling2D((2, 2)))
# Разворачиваем изображение в вектор
model.add(Flatten())
# Полносвязные слои
#model.add(layers.SimpleRNN(128, activation = 'relu'))
model.add(Dense(units=120, activation='relu'))
model.add(layers.Dropout(0.1))
model.add(Dense(units=84, activation='relu'))
#model.add(LSTM(128,activation = 'relu'))
model.add(Dense(units=output_shape, activation = 'relu'))
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              metrics=['acc','mse'])
# Out:
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 17, 21, 5)         85
# _________________________________________________________________
# average_pooling2d_15 (Averag (None, 8, 10, 5)          0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 6, 8, 16)          736
# _________________________________________________________________
# average_pooling2d_16 (Averag (None, 3, 4, 16)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 120)               23160
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_71 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 34,230
# Trainable params: 34,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
test, train, target_test, target_train = train_test_split(data_1.reshape([-1,20, 24,1]), target_1, train_size=0.8,shuffle = False)
model.fit(train, target_train, epochs=10 )
prediction = model.predict(test)
#f1_score(prediction,target_test)#, accuracy_score(prediction,target_test)
(target_test-prediction.flatten()).max()
# Out:
# Epoch 1/10
# 544/544 [==============================] - 0s 303us/step - loss: 0.5072 - acc: 0.1305 - mse: 0.0162
# Epoch 2/10
# 544/544 [==============================] - 0s 465us/step - loss: 0.5104 - acc: 0.1379 - mse: 0.0125
# Epoch 3/10
# 544/544 [==============================] - 0s 577us/step - loss: 0.5109 - acc: 0.1379 - mse: 0.0142
# Epoch 4/10
# 544/544 [==============================] - 0s 549us/step - loss: 0.5620 - acc: 0.1360 - mse: 0.0300
# Epoch 5/10
# 544/544 [==============================] - 0s 442us/step - loss: 0.5466 - acc: 0.1360 - mse: 0.0295
# Epoch 6/10
# 544/544 [==============================] - 0s 498us/step - loss: 0.5168 - acc: 0.1379 - mse: 0.0169
# Epoch 7/10
# 544/544 [==============================] - 0s 393us/step - loss: 0.5076 - acc: 0.1379 - mse: 0.0146
# Epoch 8/10
# 544/544 [==============================] - 0s 415us/step - loss: 0.5128 - acc: 0.1379 - mse: 0.0132
# Epoch 9/10
# 544/544 [==============================] - 0s 628us/step - loss: 0.5066 - acc: 0.1379 - mse: 0.0133
# Epoch 10/10
# 544/544 [==============================] - 0s 591us/step - loss: 0.5075 - acc: 0.1342 - mse: 0.0132
# 0.3165868914273491

# %% [markdown]
# Обучение на выделенных данных

# %% [markdown]
# зарисовка мел коэффициентов

# %%
for i in data_2:
    librosa.display.specshow(i)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b275c9e9afba> in <module>
# ----> 1 for i in data_2:
#       2     librosa.display.specshow(i)
#       3     plt.show()
#
# NameError: name 'data_2' is not defined

# %% [markdown]
# формирование данных

# %%
name = 'fast'

# %%
def data_prep(name, wide_w= 12288, st= 512):
    new_era = Bront(1,1)
    start_mr, end_mr = new_era._get_mark("data/marks/source/"+name+"__mark.txt")
    pcm,sr = librosa.load("data/wav/"+name+".wav")
    bag_range = range(0,pcm.shape[0], st)
    test_mark_1 = np.zeros(len(bag_range))
    k = 0
    for i,i_step in enumerate(bag_range):
        if end_mr[k]<i_step:
            k+=1
            if k>=end_mr.shape[0]:
                break
        pr_1 = 1- (max(i_step-start_mr[k], 0)+
                   max(0, end_mr[k]- i_step-wide_w))/(end_mr[k]- start_mr[k])
            
        if (k+1)<end_mr.shape[0]:
            pr_2 = 1- (max(i_step-start_mr[k+1], 0)+
                       max(end_mr[k+1]- i_step-wide_w, 0))/(end_mr[k+1]- start_mr[k+1]) 
        else :
            pr_2 = 0
        test_mark_1[i]= max(0., pr_1, pr_2)
    ((end_mr - start_mr)).max()
    
    data_1 = np.load("data/dt_1/"+name+"__mfcc__data.npy")#.reshape([-1,120])
    return data_1, test_mark_1
    

data_1, test_mark_1 = data_prep('clear')
true_data_2 = data_1[test_mark_1==1][4::8][:40]
true_target = np.ones(true_data_2.shape[0])
false_data_2 = data_1[test_mark_1<0.2][:40]
false_target = np.zeros(false_data_2.shape[0])
data_2 = np.concatenate((true_data_2, false_data_2), axis=0)
target_2 =  np.concatenate((true_target, false_target), axis=0)
data_2.shape, target_2.shape
data_1_flat = data_1.reshape(-1,480)

# %%
data_1 = np.load("data/dt_1/"+name+"__mfcc__data.npy")#.reshape([-1,120])
target_1 = test_mark_1
data_1.shape, target_1.shape
# Out:
# ((2689, 20, 24), (2716,))

# %%
test_drive = Bront(24,1)
path_wav = "data/wav/"
path_features_save = "data/feat_1/"
test_drive.feature_ex_and_safe(path_wav , path_features_save)
test_drive.data_maker("data/feat_1/","data/dt_1/")
# Out:
# data/feat_1/chips__mfcc.npy
# data/feat_1/clear__mfcc.npy
# data/feat_1/fast__mfcc.npy
# data/feat_1/music__mfcc.npy
# data/feat_1/speak__mfcc.npy
# data/feat_1/sport__mfcc.npy
# data/dt_1/chips__mfcc__data.npy
# data/dt_1/clear__mfcc__data.npy
# data/dt_1/fast__mfcc__data.npy
# data/dt_1/music__mfcc__data.npy
# data/dt_1/speak__mfcc__data.npy
# data/dt_1/sport__mfcc__data.npy

# %%
true_data_2 = data_1[target_1==1][4::8][:40]
true_target = np.ones(true_data_2.shape[0])
false_data_2 = data_1[target_1<0.2][:40]
false_target = np.zeros(false_data_2.shape[0])
data_2 = np.concatenate((true_data_2, false_data_2), axis=0)
target_2 =  np.concatenate((true_target, false_target), axis=0)
data_2.shape, target_2.shape
data_1_flat = data_1.reshape(-1,480)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-14ac5bdabb9a> in <module>
# ----> 1 true_data_2 = data_1[target_1==1][4::8][:40]
#       2 true_target = np.ones(true_data_2.shape[0])
#       3 false_data_2 = data_1[target_1<0.2][:40]
#       4 false_target = np.zeros(false_data_2.shape[0])
#       5 data_2 = np.concatenate((true_data_2, false_data_2), axis=0)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2689 but corresponding boolean dimension is 2716

# %% [markdown]
# подключение библиотек

# %%
import sklearn
from sklearn.model_selection import train_test_split  
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import auc

# %% [markdown]
# К-ближайщих соседей

# %%
from sklearn.neighbors import KNeighborsClassifier
test, train, target_test, target_train = train_test_split(data_2.reshape([-1,480]), target_2, train_size=0.2,shuffle =True)
model_KNC = KNeighborsClassifier(n_neighbors= 3).fit(train,target_train)
predict_knc = model_KNC.predict(test)
f1_score(predict_knc,target_test), accuracy_score(predict_knc,target_test)
# Out:
# (1.0, 1.0)

# %%
# %%time
test, train, target_test, target_train = train_test_split(data_2.reshape([-1,480]), target_2, train_size=0.2,shuffle =True)
koefs = np.arange(1,60, step=1)
f1 = np.zeros(koefs.shape[0])
acc = np.zeros(koefs.shape[0])
for i,koef in enumerate(koefs):
    model_KNC1 = KNeighborsClassifier(n_neighbors= koef).fit(train,target_train)
    global_pred_knc1 = model_KNC1.predict(data_1_flat)
    f1[i], acc[i] = f1_score(global_pred_knc1,(target_1==1)), accuracy_score(global_pred_knc1,(target_1==1))
print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
plt.figure(figsize=[20,10])
plt.plot(koefs,f1, label="f1")
plt.plot(koefs, acc, label="accuracy")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('Колличество соседей', fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()
# Out:
# 0.6094339622641509 46 0.8483063328424153 44
# Wall time: 17.6 s

# %% [markdown]
# Обычный персепртон

# %%
test, train, target_test, target_train = train_test_split(data_2.reshape([-1,480]), target_2, train_size=0.2,shuffle =True)
input_shape = (20, 24, 1)
output_shape = 1

model_per = Sequential()

#model.add(layers.SimpleRNN(128, activation = 'relu'))
model_per.add(Dense(units=480, activation='relu'))
#model.add(layers.Dropout(0.1))
#model.add(LSTM(128,activation = 'relu'))
model_per.add(Dense(units=output_shape, activation = 'relu'))

model_per.compile(optimizer=keras.optimizers.Adam(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              #metrics=['acc','mse'])
                 )
model_per.fit(train, target_train, epochs= 10)
model_per.summary()
predict_nn = (model_per.predict(test).flatten()>1)
f1_score(predict_nn,target_test), accuracy_score(predict_nn,target_test)
# Out:
# W0905 13:05:34.665743  3604 deprecation_wrapper.py:119] From C:\Users\Mac\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0905 13:05:34.690744  3604 deprecation_wrapper.py:119] From C:\Users\Mac\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0905 13:05:35.674800  3604 deprecation.py:323] From C:\Users\Mac\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0905 13:05:35.826809  3604 deprecation_wrapper.py:119] From C:\Users\Mac\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0905 13:05:36.124826  3604 deprecation_wrapper.py:119] From C:\Users\Mac\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/10
# 64/64 [==============================] - ETA: 1s - loss: 5.412 - 1s 18ms/step - loss: 2.7405
# Epoch 2/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 719us/step - loss: 0.0000e+00
# Epoch 3/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 578us/step - loss: 0.0000e+00
# Epoch 4/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 828us/step - loss: 0.0000e+00
# Epoch 5/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 516us/step - loss: 0.0000e+00
# Epoch 6/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 531us/step - loss: 0.0000e+00
# Epoch 7/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 578us/step - loss: 0.0000e+00
# Epoch 8/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 547us/step - loss: 0.0000e+00
# Epoch 9/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 594us/step - loss: 0.0000e+00
# Epoch 10/10
# 64/64 [==============================] - ETA: 0s - loss: 0.0000e+0 - 0s 516us/step - loss: 0.0000e+00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 480)               230880
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 481
# =================================================================
# Total params: 231,361
# Trainable params: 231,361
# Non-trainable params: 0
# _________________________________________________________________
# (1.0, 1.0)

# %%
names = ['clear','chips', 'music', 'fast']
for name in names:
    data_p, target_p = data_prep(name)
    print(data_p.shape, target_p.shape)
    data_flat = data_p.reshape([-1,480])
    global_pred_nn = model_per.predict(data_flat).flatten()
    koefs = np.arange(0,10, step=0.1)
    f1 = np.zeros(koefs.shape[0])
    acc = np.zeros(koefs.shape[0])
    for i,koef in enumerate(koefs):
        f1[i], acc[i] = f1_score(global_pred_nn>koef,(target_p==1)), accuracy_score(global_pred_nn>koef,(target_p==1))
    print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
    plt.figure(figsize=[20,10])
    plt.plot(koefs,f1, label="f1")
    plt.plot(koefs, acc, label="accuracy")
    plt.ylabel('Метрика точности', fontsize=26)
    plt.xlabel('пороговый коффициент, выше которого ответ нн считается 1', fontsize=26)
    plt.title(name,fontsize=26)
    plt.grid()
    plt.legend(fontsize=26)
    plt.show()
# Out:
# (2716, 20, 24) (2716,)
# 0.8064085447263017 8.6 0.9473490427098674 9.1
# (2707, 20, 24) (2707,)
# 0.2413987591652566 0.0 0.8263760620613225 9.8
# (5074, 20, 24) (5074,)
# 0.7673179396092362 3.7 0.9278675601103665 4.3
# (2689, 20, 24) (2689,)
# 0.8167539267015708 6.300000000000001 0.9352919300855337 6.4

# %% [markdown]
# Анализ результатов

# %%
name = names[0]
data_p, target_p = data_prep(name)
print(data_p.shape, target_p.shape)
data_flat = data_p.reshape([-1,480])
global_pred_nn = model_per.predict(data_flat).flatten()
# Out:
# (2716, 20, 24) (2716,)

# %%
pred = global_pred_nn>8.6
tar = (target_p==1)
pred[tar==1].sum()/pred[tar==1].shape[0]
# Out:
# 0.8703170028818443

# %%
win = [0,-1]
plt.figure(figsize=[20,10])
plt.plot(tar[win[0]:win[1]])
plt.plot(pred[win[0]:win[1]])
plt.plot(target_p[win[0]:win[1]])

# %%
n_tar = 0
n_pred = 0
for i in range(1,tar.shape[0]):
    if tar[i]!=tar[i-1]:
        n_tar +=1
    if pred[i]!=pred[i-1]:
        n_pred +=1   
n_pred, n_tar
# Out:
# (170, 154)

# %%
pred_nn = global_pred_nn>7.6
#librosa.display.specshow(test._mfcc(x[st:en]), x_axis='time')
for st in data_1[(pred_nn != (target_1==1))]:
    librosa.display.specshow(st, x_axis='time')
    plt.show()

# %% [markdown]
# Сверточная нн

# %%
test, train, target_test, target_train = train_test_split(data_2.reshape([-1,20,24,1]), target_2, train_size=0.2,shuffle =True)
input_shape = (20, 24, 1)
output_shape = 1

model_cnn = Sequential()
model_cnn.add(Conv2D(5, kernel_size=(4, 4),
                 activation='relu',
                 input_shape=input_shape))
model_cnn.add(AveragePooling2D((2, 2)))
model_cnn.add(Flatten())
# Полносвязные слои
model_cnn.add(Dense(units=120, activation='relu'))
model_cnn.add(layers.Dropout(0.1))
model_cnn.add(Dense(units=84, activation='relu'))
#model.add(LSTM(128,activation = 'relu'))
model_cnn.add(Dense(units=output_shape, activation = 'relu'))

model_cnn.compile(optimizer=tf.keras.optimizers.Adam(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              metrics=['acc','mse'])
model_cnn.fit(train, target_train, epochs=3)
model_cnn.summary()
predict_cnn = model_cnn.predict(test)>1
f1_score(predict_cnn,target_test), accuracy_score(predict_cnn,target_test)
# Out:
# Epoch 1/3
# 64/64 [==============================] - 0s 3ms/step - loss: 7.5504 - acc: 0.4844 - mse: 0.5104
# Epoch 2/3
# 64/64 [==============================] - 0s 297us/step - loss: 7.4854 - acc: 0.5000 - mse: 0.4898
# Epoch 3/3
# 64/64 [==============================] - 0s 359us/step - loss: 6.9024 - acc: 0.5156 - mse: 0.4790
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 17, 21, 5)         85
# _________________________________________________________________
# average_pooling2d_14 (Averag (None, 8, 10, 5)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 400)               0
# _________________________________________________________________
# dense_65 (Dense)             (None, 120)               48120
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_66 (Dense)             (None, 84)                10164
# _________________________________________________________________
# dense_67 (Dense)             (None, 1)                 85
# =================================================================
# Total params: 58,454
# Trainable params: 58,454
# Non-trainable params: 0
# _________________________________________________________________
# (0.0, 0.5)

# %%
global_pred_cnn = model_cnn.predict(data_1.reshape([-1,20,24,1])).flatten()
koefs = np.arange(0,1, step=0.02)
f1 = np.zeros(koefs.shape[0])
acc = np.zeros(koefs.shape[0])
for i,koef in enumerate(koefs):
    f1[i], acc[i] = f1_score(global_pred_cnn>1.6,(target_1>=koef)), accuracy_score(global_pred_cnn>1.6,(target_1>=koef))
print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
plt.figure(figsize=[20,10])
plt.plot(koefs,f1)
plt.plot(koefs, acc)
plt.plot(koefs,f1, label="f1")
plt.plot(koefs, acc, label="accuracy")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('Часть попадающего в окно сердцебиения', fontsize=26)
plt.title('',fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()
# Out:
# 0.0 0.0 0.8475699558173785 0.98

# %%
global_pred_cnn = model_cnn.predict(data_1.reshape([-1,20,24,1])).flatten()
koefs = np.arange(0,3, step=0.1)
f1 = np.zeros(koefs.shape[0])
acc = np.zeros(koefs.shape[0])
for i,koef in enumerate(koefs):
    f1[i], acc[i] = f1_score(global_pred_cnn>koef,(target_1==1)), accuracy_score(global_pred_cnn>koef,(target_1==1))
print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
plt.figure(figsize=[20,10])
plt.plot(koefs,f1, label="f1")
plt.plot(koefs, acc, label="accuracy")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('коффициент, выше которого ответ нн считается 1', fontsize=26)
plt.title('зависимость точности от интерпритации ответа нн',fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()
# Out:
# 0.39933993399339934 0.0 0.8729749631811488 0.5

# %% [markdown]
# Поиск выборки

# %%
model_per_1 = Sequential()

#model.add(layers.SimpleRNN(128, activation = 'relu'))
model_per_1.add(Dense(units=480, activation='relu'))
#model.add(layers.Dropout(0.1))
#model.add(LSTM(128,activation = 'relu'))
model_per_1.add(Dense(units=output_shape, activation = 'relu'))

model_per_1.compile(optimizer=keras.optimizers.Adam(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              #metrics=['acc','mse'])
                 )

# %%
data_1, test_mark_1 = data_prep('clear')
true_data_2 = data_1[test_mark_1==1][4::8][:40]
true_target = np.ones(true_data_2.shape[0])
false_data_2 = data_1[test_mark_1<0.2][:40]
false_target = np.zeros(false_data_2.shape[0])
data_2 = np.concatenate((true_data_2, false_data_2), axis=0)
target_2 =  np.concatenate((true_target, false_target), axis=0)

# %%
# %%time
name = names[0]
data_p, target_p = data_prep(name)
print(data_p.shape, target_p.shape)
target_p = target_p==1
data_flat = data_p.reshape([-1,480])
final_data = np.empty([0,480])#data_2.reshape([-1,480])
final_target = np.empty([0])#target_2
temp_f1 = 0
for i,d in enumerate(data_flat[:200]):
    #print(test_mark_1[i], final_target.shape)
    temp_data = np.concatenate((final_data, d.reshape([1,-1])), axis=0)
    temp_target = np.append(final_target, test_mark_1[i])
    
    new_model= Sequential()

    #model.add(layers.SimpleRNN(128, activation = 'relu'))
    new_model.add(Dense(units=480, activation='relu'))
    #model.add(layers.Dropout(0.1))
    #model.add(LSTM(128,activation = 'relu'))
    new_model.add(Dense(units=output_shape, activation = 'relu'))
    
    new_model.compile(optimizer=keras.optimizers.Adam(), 
              loss =tf.keras.losses.BinaryCrossentropy(), 
              #metrics=['acc','mse'])
                 )
    new_model.fit(temp_data, temp_target, epochs= 3)
    #print(temp_f1)
    
    global_pred_nn = new_model.predict(data_flat)
    koefs = np.arange(0,200, step=1)
    f1 = np.zeros(koefs.shape[0])
    acc = np.zeros(koefs.shape[0])

    for i,koef in enumerate(koefs):
        f1[i], acc[i] = f1_score(global_pred_nn>koef,(target_p==1)), accuracy_score(global_pred_nn>koef,(target_p==1))
    print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
    
    if f1.max()>temp_f1:
        temp_f1 = f1.max()
        final_data = np.concatenate((final_data, d.reshape([1,-1])), axis=0)
        final_target = np.append(final_target, test_mark_1[i])
# Out:
# (2716, 20, 24) (2716,)
# Epoch 1/3
# 1/1 [==============================] - 4s 4s/step - loss: 13.6482
# Epoch 2/3
# 1/1 [==============================] - 0s 32ms/step - loss: 13.6482
# Epoch 3/3
# 1/1 [==============================] - 0s 56ms/step - loss: 13.6482
# 0.31438127090301005 0 0.8722385861561119 4
# Epoch 1/3
# 2/2 [==============================] - 3s 2s/step - loss: 13.0939
# Epoch 2/3
# 2/2 [==============================] - 0s 9ms/step - loss: 13.0939
# Epoch 3/3
# 2/2 [==============================] - 0s 7ms/step - loss: 13.0939
# 0.25217391304347825 0 0.8722385861561119 2
# Epoch 1/3
# 2/2 [==============================] - 4s 2s/step - loss: 8.3184
# Epoch 2/3
# 2/2 [==============================] - 0s 7ms/step - loss: 2.6022
# Epoch 3/3
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8783
# 0.03271375464684015 0 0.8722385861561119 8
# Epoch 1/3
# 2/2 [==============================] - 3s 2s/step - loss: 5.8230
# Epoch 2/3
# 2/2 [==============================] - 0s 8ms/step - loss: 5.8230
# Epoch 3/3
# 2/2 [==============================] - 0s 5ms/step - loss: 5.8230
# 0.34662327095199347 1 0.8722385861561119 5
# Epoch 1/3
# 3/3 [==============================] - 4s 1s/step - loss: 8.1139
# Epoch 2/3
# 3/3 [==============================] - 0s 4ms/step - loss: 5.1342
# Epoch 3/3
# 3/3 [==============================] - 0s 3ms/step - loss: 5.1342
# 0.3359013867488444 2 0.8726067746686303 6
# Epoch 1/3
# 3/3 [==============================] - 4s 1s/step - loss: 5.2860
# Epoch 2/3
# 3/3 [==============================] - 0s 10ms/step - loss: 5.1342
# Epoch 3/3
# 3/3 [==============================] - 0s 3ms/step - loss: 5.1342
# 0.4525316455696203 2 0.8877025036818851 3
# Epoch 1/3
# 4/4 [==============================] - 4s 926ms/step - loss: 6.0541
# Epoch 2/3
# 4/4 [==============================] - 0s 5ms/step - loss: 2.9013
# Epoch 3/3
# 4/4 [==============================] - 0s 5ms/step - loss: 2.8174
# 0.47656250000000006 2 0.8891752577319587 3
# Epoch 1/3
# 5/5 [==============================] - 4s 771ms/step - loss: 8.7619
# Epoch 2/3
# 5/5 [==============================] - 0s 3ms/step - loss: 8.7048
# Epoch 3/3
# 5/5 [==============================] - 0s 3ms/step - loss: 10.8239
# 0.07162842753217684 0 0.8722385861561119 8
# Epoch 1/3
# 5/5 [==============================] - 4s 758ms/step - loss: 4.0190
# Epoch 2/3
# 5/5 [==============================] - 0s 1ms/step - loss: 6.1610
# Epoch 3/3
# 5/5 [==============================] - 0s 2ms/step - loss: 5.5253
# 0.2190082644628099 3 0.8748159057437408 4
# Epoch 1/3
# 5/5 [==============================] - 4s 803ms/step - loss: 4.7808
# Epoch 2/3
# 5/5 [==============================] - 0s 7ms/step - loss: 6.0413
# Epoch 3/3
# 5/5 [==============================] - 0s 8ms/step - loss: 6.0413
# 0.27960526315789475 1 0.8726067746686303 4
# Epoch 1/3
# 5/5 [==============================] - 4s 732ms/step - loss: 9.9837
# Epoch 2/3
# 5/5 [==============================] - 0s 2ms/step - loss: 9.0184
# Epoch 3/3
# 5/5 [==============================] - 0s 4ms/step - loss: 9.0184
# 0.5209125475285171 2 0.9072164948453608 2
# Epoch 1/3
# 6/6 [==============================] - 4s 629ms/step - loss: 3.1089
# Epoch 2/3
# 6/6 [==============================] - 0s 1ms/step - loss: 4.2488
# Epoch 3/3
# 6/6 [==============================] - 0s 3ms/step - loss: 4.7819
# 0.4298245614035088 2 0.874079528718704 4
# Epoch 1/3
# 6/6 [==============================] - 4s 654ms/step - loss: 11.7883
# Epoch 2/3
# 6/6 [==============================] - 0s 2ms/step - loss: 11.7883
# Epoch 3/3
# 6/6 [==============================] - 0s 3ms/step - loss: 11.7883
# 0.042440318302387266 0 0.8722385861561119 2
# Epoch 1/3
# 6/6 [==============================] - 4s 686ms/step - loss: 11.6393
# Epoch 2/3
# 6/6 [==============================] - 0s 4ms/step - loss: 11.6393
# Epoch 3/3
# 6/6 [==============================] - 0s 3ms/step - loss: 11.6393
# 0.07930607187112762 0 0.8722385861561119 3
# Epoch 1/3
# 6/6 [==============================] - 4s 738ms/step - loss: 6.5426
# Epoch 2/3
# 6/6 [==============================] - 0s 3ms/step - loss: 7.5457
# Epoch 3/3
# 6/6 [==============================] - 0s 2ms/step - loss: 6.3852
# 0.6019417475728155 2 0.9134756995581738 3
# Epoch 1/3
# 7/7 [==============================] - 4s 548ms/step - loss: 4.2897
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.9173
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 5.8199
# 0.15024172554853107 0 0.8722385861561119 6
# Epoch 1/3
# 7/7 [==============================] - 4s 605ms/step - loss: 5.5650
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.7491
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.3230
# 0.3822843822843823 1 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 4s 556ms/step - loss: 8.6813
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.4697
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.4766
# 0.18594104308390022 0 0.8722385861561119 9
# Epoch 1/3
# 7/7 [==============================] - 4s 561ms/step - loss: 6.3311
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 9.8749
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 9.8749
# 0.06019151846785225 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 4s 563ms/step - loss: 7.8433
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 7.1987
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.4932
# 0.06859592711682742 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 4s 569ms/step - loss: 10.7467
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.7467
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.7467
# 0.06349206349206349 0 0.8722385861561119 2
# Epoch 1/3
# 7/7 [==============================] - 4s 607ms/step - loss: 3.2370
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 3.3487
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 3.8567
# 0.424390243902439 2 0.8755522827687776 3
# Epoch 1/3
# 7/7 [==============================] - 4s 586ms/step - loss: 7.4591
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.6769
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.1584
# 0.23843222645617854 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 4s 628ms/step - loss: 10.0575
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 8.9874
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 9.2367
# 0.32094594594594594 0 0.8726067746686303 3
# Epoch 1/3
# 7/7 [==============================] - 5s 723ms/step - loss: 8.4761
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.2361
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.2361
# 0.5089141004862237 0 0.8884388807069219 0
# Epoch 1/3
# 7/7 [==============================] - 5s 648ms/step - loss: 5.9847
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 3.9668
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5539
# 0.302571860816944 1 0.8722385861561119 6
# Epoch 1/3
# 7/7 [==============================] - 4s 619ms/step - loss: 3.1902
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 5.8044
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.8044
# 0.31773399014778325 1 0.8722385861561119 6
# Epoch 1/3
# 7/7 [==============================] - 4s 602ms/step - loss: 5.5790
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 7.0550
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.0550
# 0.5114345114345116 1 0.8792341678939617 2
# Epoch 1/3
# 7/7 [==============================] - 4s 618ms/step - loss: 3.8863
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.0287
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.3055
# 0.17837507635919364 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 4s 615ms/step - loss: 7.0643
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 3.9726
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.0479
# 0.2941777323799796 0 0.8722385861561119 10
# Epoch 1/3
# 7/7 [==============================] - 5s 651ms/step - loss: 5.3537
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.6694
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.9720
# 0.39999999999999997 1 0.875920471281296 3
# Epoch 1/3
# 7/7 [==============================] - 4s 622ms/step - loss: 5.3038
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 6.4219
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.4219
# 0.4330578512396695 2 0.882179675994109 3
# Epoch 1/3
# 7/7 [==============================] - 5s 676ms/step - loss: 1.5338
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 4.2913
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.2913
# 0.25386493083807976 0 0.8722385861561119 6
# Epoch 1/3
# 7/7 [==============================] - 5s 680ms/step - loss: 9.6552
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.0501
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.0501
# 0.14582023884349465 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 691ms/step - loss: 3.7410
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 5.6653
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.6653
# 0.5047846889952153 2 0.8792341678939617 3
# Epoch 1/3
# 7/7 [==============================] - 4s 637ms/step - loss: 6.1179
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.3582
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.3582
# 0.22279792746113994 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 682ms/step - loss: 10.0139
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4205
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 9.0357
# 0.11616161616161617 0 0.8722385861561119 9
# Epoch 1/3
# 7/7 [==============================] - 5s 762ms/step - loss: 1.7129
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.5678
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.9857
# 0.11921032649962034 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 702ms/step - loss: 8.6887
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.6675
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.6675
# 0.3065868263473054 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 674ms/step - loss: 5.7740
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.9867
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.0545
# 0.5757575757575757 2 0.9101620029455081 3
# Epoch 1/3
# 7/7 [==============================] - 5s 705ms/step - loss: 10.5414
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9145
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 8.9607
# 0.15384615384615385 1 0.8729749631811488 5
# Epoch 1/3
# 7/7 [==============================] - 5s 677ms/step - loss: 2.4800
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 3.9918
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 3.4902
# 0.2251450676982592 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 722ms/step - loss: 7.0850
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.8552
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.2813
# 0.06625766871165645 0 0.8726067746686303 4
# Epoch 1/3
# 7/7 [==============================] - 5s 683ms/step - loss: 9.6426
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.1535
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.8046
# 0.5595667870036101 2 0.9101620029455081 2
# Epoch 1/3
# 7/7 [==============================] - 5s 715ms/step - loss: 7.7605
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 5.6316
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 5.4740
# 0.400355871886121 1 0.874079528718704 3
# Epoch 1/3
# 7/7 [==============================] - 5s 691ms/step - loss: 9.5063
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 8.7736
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.8046
# 0.056275122822688706 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 5s 731ms/step - loss: 5.0252
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.3469
# Epoch 3/3
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3469
# 0.5348837209302326 2 0.8906480117820325 3
# Epoch 1/3
# 7/7 [==============================] - 5s 773ms/step - loss: 5.3867
# Epoch 2/3
# 7/7 [==============================] - 0s 5ms/step - loss: 6.5505
# Epoch 3/3
# 7/7 [==============================] - 0s 5ms/step - loss: 6.5505
# 0.535 2 0.8958026509572902 3
# Epoch 1/3
# 7/7 [==============================] - 6s 846ms/step - loss: 2.4083
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 3.3028
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 3.3028
# 0.21275144902829865 0 0.8722385861561119 9
# Epoch 1/3
# 7/7 [==============================] - 7s 987ms/step - loss: 3.3192
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 4.5527
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 4.1698
# 0.5047438330170778 2 0.8766568483063328 3
# Epoch 1/3
# 7/7 [==============================] - 5s 721ms/step - loss: 8.6133
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.3346
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 7.6799
# 0.034278959810874705 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 6s 810ms/step - loss: 7.4421
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.7948
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 6.0966
# 0.2910284463894967 2 0.8744477172312224 4
# Epoch 1/3
# 7/7 [==============================] - 5s 736ms/step - loss: 3.5381
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 3.9934
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 5.0875
# 0.2683469236471461 1 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 773ms/step - loss: 6.0498
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.2978
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.7934
# 0.14415841584158415 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 744ms/step - loss: 11.3614
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 11.3614
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 11.3614
# 0.12015503875968991 0 0.8729749631811488 1
# Epoch 1/3
# 7/7 [==============================] - 6s 854ms/step - loss: 6.7899
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.9838
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.9838
# 0.11217335882727852 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 750ms/step - loss: 6.9903
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.7332
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.7332
# 0.12874493927125505 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 5s 760ms/step - loss: 4.0210
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.4827
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 6.4827
# 0.34360554699537754 1 0.8726067746686303 5
# Epoch 1/3
# 7/7 [==============================] - 5s 773ms/step - loss: 3.7504
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 4.2080
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 4.5304
# 0.2556097560975609 2 0.8726067746686303 6
# Epoch 1/3
# 7/7 [==============================] - 5s 779ms/step - loss: 8.5470
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.2230
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.4898
# 0.05331179321486268 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 6s 806ms/step - loss: 7.5451
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.9928
# Epoch 3/3
# 7/7 [==============================] - 0s 5ms/step - loss: 6.1122
# 0.32495511669658894 1 0.8729749631811488 5
# Epoch 1/3
# 7/7 [==============================] - 5s 773ms/step - loss: 8.9535
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.2428
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.2428
# 0.50814332247557 1 0.8958026509572902 2
# Epoch 1/3
# 7/7 [==============================] - 6s 815ms/step - loss: 10.0591
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5348
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 8.1193
# 0.5222929936305732 1 0.8895434462444771 1
# Epoch 1/3
# 7/7 [==============================] - 6s 792ms/step - loss: 8.7325
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.3080
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.3080
# 0.40106951871657753 0 0.8722385861561119 3
# Epoch 1/3
# 7/7 [==============================] - 6s 916ms/step - loss: 5.9832
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 6.7506
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.2077
# 0.07341176470588236 0 0.8722385861561119 5
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 7.7041
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 8.3212
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.8827
# 0.06429548563611491 0 0.8722385861561119 5
# Epoch 1/3
# 7/7 [==============================] - 6s 804ms/step - loss: 10.7090
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.7090
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.7090
# 0.02742857142857143 0 0.8722385861561119 3
# Epoch 1/3
# 7/7 [==============================] - 6s 824ms/step - loss: 7.2067
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.1101
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.8091
# 0.2964509394572025 1 0.8722385861561119 11
# Epoch 1/3
# 7/7 [==============================] - 6s 813ms/step - loss: 8.2661
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 7.5952
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.5952
# 0.5241199478487614 1 0.9042709867452136 2
# Epoch 1/3
# 7/7 [==============================] - 6s 820ms/step - loss: 4.7105
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 6.1640
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.2967
# 0.08057296329453896 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 6s 925ms/step - loss: 7.3924
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.4076
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 6.5625
# 0.06840390879478826 0 0.8722385861561119 9
# Epoch 1/3
# 7/7 [==============================] - 6s 876ms/step - loss: 6.8592
# Epoch 2/3
# 7/7 [==============================] - 0s 7ms/step - loss: 6.8691
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 5.4643
# 0.30238726790450926 2 0.8733431516936672 6
# Epoch 1/3
# 7/7 [==============================] - 6s 829ms/step - loss: 3.2907
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 5.7220
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 6.1448
# 0.3179916317991632 1 0.8722385861561119 5
# Epoch 1/3
# 7/7 [==============================] - 6s 884ms/step - loss: 10.2105
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.5176
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.5176
# 0.07424071991001124 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 6s 864ms/step - loss: 5.8198
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.9962
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.2701
# 0.5265822784810126 2 0.8950662739322534 3
# Epoch 1/3
# 7/7 [==============================] - 6s 891ms/step - loss: 10.2545
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.2545
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.2545
# 0.13431613431613432 0 0.8722385861561119 3
# Epoch 1/3
# 7/7 [==============================] - 6s 849ms/step - loss: 4.1684
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 4.4863
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 2.5796
# 0.49937264742785453 2 0.8888070692194403 3
# Epoch 1/3
# 7/7 [==============================] - 6s 854ms/step - loss: 6.8279
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 6.5440
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 6.5440
# 0.4627606752730884 2 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 6s 905ms/step - loss: 10.8474
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 8.6243
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.3330
# 0.48330683624801274 2 0.8958026509572902 3
# Epoch 1/3
# 7/7 [==============================] - 6s 865ms/step - loss: 12.1858
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 12.1858
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 12.1858
# 0.11256281407035176 0 0.8722385861561119 3
# Epoch 1/3
# 7/7 [==============================] - 7s 946ms/step - loss: 7.6011
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 6.1894
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.4116
# 0.5979899497487438 2 0.9108983799705449 3
# Epoch 1/3
# 7/7 [==============================] - 6s 886ms/step - loss: 3.7027
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.3469
# Epoch 3/3
# 7/7 [==============================] - 0s 5ms/step - loss: 4.3469
# 0.5316129032258065 2 0.8932253313696613 3
# Epoch 1/3
# 7/7 [==============================] - 6s 879ms/step - loss: 12.1858
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 12.1858
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 12.1858
# 0.08097165991902835 0 0.8722385861561119 2
# Epoch 1/3
# 7/7 [==============================] - 6s 927ms/step - loss: 4.1493
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 3.9175
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.0978
# 0.1395528141865844 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 6s 884ms/step - loss: 11.0588
# Epoch 2/3
# 7/7 [==============================] - 0s 5ms/step - loss: 11.0588
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 11.0588
# 0.1273356401384083 0 0.8722385861561119 4
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 9.4723
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.2891
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.7462
# 0.5720930232558139 1 0.9123711340206185 2
# Epoch 1/3
# 7/7 [==============================] - 7s 969ms/step - loss: 3.7314
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.6084
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.1139
# 0.502673796791444 2 0.8972754050073638 2
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 1.2748
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 2.6642
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.6708
# 0.2286442838929027 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 7.2859
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 6.6790
# Epoch 3/3
# 7/7 [==============================] - 0s 5ms/step - loss: 7.0578
# 0.12783696155627605 0 0.8726067746686303 7
# Epoch 1/3
# 7/7 [==============================] - 6s 901ms/step - loss: 11.5927
# Epoch 2/3
# 7/7 [==============================] - 0s 6ms/step - loss: 11.5927
# Epoch 3/3
# 7/7 [==============================] - 0s 3ms/step - loss: 11.5927
# 0.22145328719723184 0 0.8722385861561119 2
# Epoch 1/3
# 7/7 [==============================] - 7s 958ms/step - loss: 8.6813
# Epoch 2/3
# 7/7 [==============================] - 0s 7ms/step - loss: 10.3320
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3320
# 0.2215320910973085 1 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 6s 914ms/step - loss: 7.0864
# Epoch 2/3
# 7/7 [==============================] - 0s 4ms/step - loss: 5.9146
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.9442
# 0.17650025214321735 0 0.8726067746686303 6
# Epoch 1/3
# 7/7 [==============================] - 7s 931ms/step - loss: 2.1439
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 3.3304
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 4.2081
# 0.44549763033175355 2 0.8924889543446245 3
# Epoch 1/3
# 7/7 [==============================] - 7s 956ms/step - loss: 6.8024
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.5880
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.6769
# 0.13880855986119142 0 0.8726067746686303 5
# Epoch 1/3
# 7/7 [==============================] - 7s 931ms/step - loss: 10.9244
# Epoch 2/3
# 7/7 [==============================] - 0s 5ms/step - loss: 10.9244
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 10.9244
# 0.016042780748663103 0 0.8722385861561119 1
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 8.8636
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2420
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 10.2420
# 0.17503805175038054 0 0.8726067746686303 7
# Epoch 1/3
# 7/7 [==============================] - 7s 970ms/step - loss: 3.9717
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 5.0218
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 5.0218
# 0.5454545454545455 3 0.9061119293078056 3
# Epoch 1/3
# 7/7 [==============================] - 7s 942ms/step - loss: 6.2404
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.2302
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.2693
# 0.5833333333333334 1 0.9123711340206185 2
# Epoch 1/3
# 7/7 [==============================] - 7s 962ms/step - loss: 4.5514
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 5.0053
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.0053
# 0.2273462783171521 1 0.8722385861561119 9
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 8.6829
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 9.1290
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.1013
# 0.0779498131340096 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 3.7642
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 4.1249
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.1127
# 0.5793450881612091 2 0.9153166421207658 3
# Epoch 1/3
# 7/7 [==============================] - 7s 963ms/step - loss: 2.5314
# Epoch 2/3
# 7/7 [==============================] - 0s 3ms/step - loss: 4.6903
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 4.6903
# 0.25587467362924277 0 0.8722385861561119 8
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 7.2805
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.9235
# Epoch 3/3
# 7/7 [==============================] - 0s 4ms/step - loss: 8.1937
# 0.08528037383177568 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 10.0123
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 11.5885
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 10.1205
# 0.24144869215291753 0 0.8722385861561119 4
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 6.2394
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.3109
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.3109
# 0.1978764478764479 0 0.8722385861561119 5
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 3.5136
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 6.8359
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.1310
# 0.12533765532144786 0 0.8722385861561119 5
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 2.0676
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8736
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 3.7267
# 0.1331028522039758 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 7.1067
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.8045
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.8045
# 0.49130938586326767 1 0.896539027982327 2
# Epoch 1/3
# 7/7 [==============================] - 7s 992ms/step - loss: 0.9131
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.5455
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 5.5455
# 0.2841328413284133 0 0.8722385861561119 7
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 11.3030
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 11.3030
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 11.3030
# 0.050335570469798654 0 0.8722385861561119 2
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 8.3514
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 7.6114
# Epoch 3/3
# 7/7 [==============================] - 0s 1ms/step - loss: 8.0731
# 0.19845758354755783 0 0.8729749631811488 5
# Epoch 1/3
# 7/7 [==============================] - 7s 1s/step - loss: 8.5965
# Epoch 2/3
# 7/7 [==============================] - 0s 1ms/step - loss: 7.7098
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 8.1661
# 0.3801169590643275 1 0.8773932253313697 2
# Epoch 1/3
# 7/7 [==============================] - 8s 1s/step - loss: 10.1272
# Epoch 2/3
# 7/7 [==============================] - 0s 2ms/step - loss: 9.4153
# Epoch 3/3
# 7/7 [==============================] - 0s 2ms/step - loss: 9.4153
# 0.6257485029940119 1 0.9086892488954345 2
# Epoch 1/3
# 8/8 [==============================] - 8s 996ms/step - loss: 9.0262
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.5816
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.8011
# 0.06265539532570859 0 0.8722385861561119 6
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 6.7774
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 6.1968
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4821
# 0.11468901632112924 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 8s 976ms/step - loss: 6.6275
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 8.3482
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3482
# 0.11956521739130437 0 0.8722385861561119 6
# Epoch 1/3
# 8/8 [==============================] - 8s 976ms/step - loss: 1.7979
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3110
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9382
# 0.4518518518518519 3 0.8726067746686303 6
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 6.0450
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.7839
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.1874
# 0.07961630695443646 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 12.1183
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 12.1183
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 12.1183
# 0.05454545454545454 0 0.8722385861561119 2
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 5.5524
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 5.8240
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2922
# 0.36220472440944884 2 0.8729749631811488 6
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 5.2621
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 4.0810
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2731
# 0.48749999999999993 2 0.8869661266568483 3
# Epoch 1/3
# 8/8 [==============================] - 8s 994ms/step - loss: 8.4492
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.8006
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4172
# 0.4126149802890933 2 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 3.3030
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8930
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2731
# 0.3037716615698267 1 0.8726067746686303 6
# Epoch 1/3
# 8/8 [==============================] - 8s 975ms/step - loss: 8.9358
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2902
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2902
# 0.1596071209330878 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 8s 969ms/step - loss: 10.6325
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 10.9386
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9386
# 0.11790393013100436 0 0.8733431516936672 3
# Epoch 1/3
# 8/8 [==============================] - 8s 977ms/step - loss: 4.0514
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5441
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.5441
# 0.423500611995104 2 0.8726067746686303 4
# Epoch 1/3
# 8/8 [==============================] - 8s 964ms/step - loss: 10.3727
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7386
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5210
# 0.5250338294993234 1 0.9009572901325479 2
# Epoch 1/3
# 8/8 [==============================] - 8s 984ms/step - loss: 10.2339
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 9.6317
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 9.6317
# 0.556998556998557 1 0.9039027982326951 2
# Epoch 1/3
# 8/8 [==============================] - 8s 1s/step - loss: 5.3124
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.5093
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8353
# 0.5631067961165048 2 0.9075846833578792 3
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 6.1451
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 3.5696
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6588
# 0.24624935333678222 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 6.2451
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.0616
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0664
# 0.2547501759324419 1 0.8726067746686303 5
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 3.2934
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 5.7959
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.8371
# 0.5086848635235732 2 0.8980117820324006 3
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 3.5361
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 3.9298
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3156
# 0.3538732394366197 2 0.8737113402061856 4
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 3.0489
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 5.4219
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4219
# 0.22865738999623916 0 0.8733431516936672 5
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 7.5613
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 8.2173
# Epoch 3/3
# 8/8 [==============================] - 0s 4ms/step - loss: 7.2587
# 0.2740174672489083 0 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 8.2866
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.4955
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.3771
# 0.05623901581722319 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 9s 1s/step - loss: 8.4537
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6697
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 8.6697
# 0.11405295315682282 1 0.8726067746686303 7
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 5.0230
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.5766
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 7.5766
# 0.4813829787234043 2 0.8810751104565537 3
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 10.4891
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.4891
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.4891
# 0.004210526315789474 0 0.8722385861561119 2
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 5.4797
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2788
# Epoch 3/3
# 8/8 [==============================] - 0s 5ms/step - loss: 5.2730
# 0.10951526032315978 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 7.8809
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 9.3038
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6226
# 0.2368881118881119 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 8.6146
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8409
# Epoch 3/3
# 8/8 [==============================] - 0s 4ms/step - loss: 8.8409
# 0.030199039121482498 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 4.8758
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.9627
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 7.9627
# 0.46969696969696967 1 0.8851251840942562 2
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 6.6410
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 8.9005
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.2866
# 0.24685138539042822 0 0.8722385861561119 5
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 3.2446
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5358
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 3.9556
# 0.2549751243781095 1 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 4.2927
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 6.1270
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 6.1270
# 0.23713826366559485 0 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 7.9345
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0304
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 7.4088
# 0.41346153846153844 2 0.8843888070692194 3
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 5.4685
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.5190
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.9122
# 0.23212192262602577 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 4.3939
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 3.6329
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7910
# 0.0747011952191235 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 10.2947
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 9.4672
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2583
# 0.05664830841856805 0 0.8722385861561119 5
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 3.1949
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 4.6038
# Epoch 3/3
# 8/8 [==============================] - 0s 4ms/step - loss: 4.6038
# 0.24774193548387097 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 8.9396
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 10.9076
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 9.5600
# 0.28034682080924855 1 0.8729749631811488 5
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 8.1865
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3475
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.3475
# 0.10055180870631514 0 0.8729749631811488 5
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 9.8036
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 12.1099
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.8220
# 0.1312741312741313 0 0.8722385861561119 3
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 9.0083
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 7.8230
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2827
# 0.2775119617224881 2 0.8737113402061856 4
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 4.2438
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 8.1736
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 8.1736
# 0.04385026737967915 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 8.2468
# Epoch 2/3
# 8/8 [==============================] - 0s 1ms/step - loss: 8.0072
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8106
# 0.2022963367960634 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 5.6176
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.9192
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.2317
# 0.6179104477611941 2 0.9160530191458026 3
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 4.0612
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.4809
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0465
# 0.3443895553987297 2 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 7.3966
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 7.8016
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 6.5937
# 0.14410705095213586 0 0.8726067746686303 6
# Epoch 1/3
# 8/8 [==============================] - 10s 1s/step - loss: 4.8048
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2560
# Epoch 3/3
# 8/8 [==============================] - 0s 1ms/step - loss: 5.0935
# 0.5607064017660043 2 0.9057437407952872 3
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 5.8945
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.3241
# Epoch 3/3
# 8/8 [==============================] - 0s 6ms/step - loss: 6.3905
# 0.19477434679334918 0 0.8722385861561119 4
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 5.5064
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7633
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.5840
# 0.27288428324697755 1 0.8722385861561119 6
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 7.8198
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.9674
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.6362
# 0.08486118386589837 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 6.3110
# Epoch 2/3
# 8/8 [==============================] - 0s 5ms/step - loss: 6.7574
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.7574
# 0.2660550458715596 1 0.8726067746686303 8
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 7.8607
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.2889
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.8648
# 0.13104383190239494 0 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 13s 2s/step - loss: 2.8177
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 6.5783
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 7.9584
# 0.15008431703204048 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 4.9286
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.2093
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.1073
# 0.3361963190184049 2 0.8796023564064801 3
# Epoch 1/3
# 8/8 [==============================] - 11s 1s/step - loss: 8.5224
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 7.8337
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.0853
# 0.28824273072060685 0 0.8722385861561119 4
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 7.4308
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.3181
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 8.2806
# 0.5564738292011019 2 0.9075846833578792 3
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 10.9550
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9550
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.9550
# 0.1248470012239902 0 0.8722385861561119 2
# Epoch 1/3
# 8/8 [==============================] - 12s 2s/step - loss: 3.7946
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.7518
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.5507
# 0.23480375130253558 0 0.8722385861561119 10
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 9.7528
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7528
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.7528
# 0.04559270516717325 0 0.8722385861561119 3
# Epoch 1/3
# 8/8 [==============================] - 12s 2s/step - loss: 5.9908
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 6.6862
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.4158
# 0.166747927840078 0 0.8726067746686303 6
# Epoch 1/3
# 8/8 [==============================] - 15s 2s/step - loss: 6.2498
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.0889
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 5.2547
# 0.3246425567703953 1 0.8726067746686303 5
# Epoch 1/3
# 8/8 [==============================] - 12s 2s/step - loss: 3.0670
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3870
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 4.3490
# 0.18071727992547743 0 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 16s 2s/step - loss: 9.3935
# Epoch 2/3
# 8/8 [==============================] - 0s 3ms/step - loss: 7.2291
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.4374
# 0.05356055995130858 0 0.8722385861561119 7
# Epoch 1/3
# 8/8 [==============================] - 16s 2s/step - loss: 4.7822
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3762
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 3.9708
# 0.2620689655172414 1 0.8722385861561119 10
# Epoch 1/3
# 8/8 [==============================] - 13s 2s/step - loss: 8.3867
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 9.9937
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.9937
# 0.18099547511312214 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 13s 2s/step - loss: 8.9618
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7331
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 7.7465
# 0.022222222222222223 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 12s 2s/step - loss: 9.9431
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.2052
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 10.2052
# 0.07259786476868328 0 0.8722385861561119 10
# Epoch 1/3
# 8/8 [==============================] - 17s 2s/step - loss: 3.4772
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 4.9890
# Epoch 3/3
# 8/8 [==============================] - 0s 2ms/step - loss: 6.3662
# 0.23395270270270271 0 0.8722385861561119 9
# Epoch 1/3
# 8/8 [==============================] - 13s 2s/step - loss: 5.1278
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 4.0997
# Epoch 3/3
# 8/8 [==============================] - 0s 6ms/step - loss: 4.4996
# 0.5377049180327869 3 0.8961708394698086 3
# Epoch 1/3
# 8/8 [==============================] - 13s 2s/step - loss: 2.8080
# Epoch 2/3
# 8/8 [==============================] - 0s 4ms/step - loss: 3.0933
# Epoch 3/3
# 8/8 [==============================] - 0s 5ms/step - loss: 3.1796
# 0.2229752626228397 0 0.8722385861561119 8
# Epoch 1/3
# 8/8 [==============================] - 12s 1s/step - loss: 10.2612
# Epoch 2/3
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6420
# Epoch 3/3
# 8/8 [==============================] - 0s 3ms/step - loss: 9.6420
# 0.6951026856240128 2 0.928939617083947 2
# Epoch 1/3
# 9/9 [==============================] - 13s 1s/step - loss: 10.4800
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 9.8272
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 8.5953
# 0.0606060606060606 0 0.8722385861561119 10
# Epoch 1/3
# 9/9 [==============================] - 13s 1s/step - loss: 6.9789
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 7.6376
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 4.4113
# 0.18840579710144925 1 0.8726067746686303 7
# Epoch 1/3
# 9/9 [==============================] - 16s 2s/step - loss: 10.7567
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 11.0233
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 11.0233
# 0.10970464135021095 0 0.8722385861561119 9
# Epoch 1/3
# 9/9 [==============================] - 13s 1s/step - loss: 9.8927
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 10.2407
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 8.7690
# 0.12947831552482716 0 0.8722385861561119 9
# Epoch 1/3
# 9/9 [==============================] - 11s 1s/step - loss: 9.6830
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 11.1892
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 8.9626
# 0.027538726333907058 0 0.8722385861561119 7
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 8.7510
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 7.8955
# Epoch 3/3
# 9/9 [==============================] - 0s 1ms/step - loss: 6.8867
# 0.5467836257309941 2 0.9086892488954345 3
# Epoch 1/3
# 9/9 [==============================] - 11s 1s/step - loss: 2.1882
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 3.3391
# Epoch 3/3
# 9/9 [==============================] - 0s 3ms/step - loss: 3.3391
# 0.15766164747564215 2 0.8726067746686303 6
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 5.9923
# Epoch 2/3
# 9/9 [==============================] - 0s 3ms/step - loss: 5.6961
# Epoch 3/3
# 9/9 [==============================] - 0s 1ms/step - loss: 4.7433
# 0.34508816120906805 2 0.8737113402061856 4
# Epoch 1/3
# 9/9 [==============================] - 11s 1s/step - loss: 11.0614
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 11.1892
# Epoch 3/3
# 9/9 [==============================] - 0s 1ms/step - loss: 9.9659
# 0.04709840201850295 0 0.8722385861561119 8
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 5.1106
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 5.6179
# Epoch 3/3
# 9/9 [==============================] - 0s 3ms/step - loss: 5.9689
# 0.2837209302325581 1 0.8722385861561119 5
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 2.5582
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 3.0795
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 3.3827
# 0.2595482546201232 0 0.8722385861561119 7
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 11.0514
# Epoch 2/3
# 9/9 [==============================] - 0s 4ms/step - loss: 11.0514
# Epoch 3/3
# 9/9 [==============================] - 0s 1ms/step - loss: 11.0514
# 0.12581344902386116 0 0.8722385861561119 3
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 8.2178
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 9.7281
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 10.9574
# 0.06056701030927835 0 0.8722385861561119 8
# Epoch 1/3
# 9/9 [==============================] - 11s 1s/step - loss: 3.5213
# Epoch 2/3
# 9/9 [==============================] - 0s 1ms/step - loss: 4.1945
# Epoch 3/3
# 9/9 [==============================] - 0s 1ms/step - loss: 5.4163
# 0.4128 3 0.8784977908689249 4
# Epoch 1/3
# 9/9 [==============================] - 10s 1s/step - loss: 5.7869
# Epoch 2/3
# 9/9 [==============================] - 0s 2ms/step - loss: 7.2629
# Epoch 3/3
# 9/9 [==============================] - 0s 2ms/step - loss: 7.2629
# 0.13720073664825044 0 0.8722385861561119 9
# Wall time: 41min 12s

# %%
temp_f1, final_data.shape
# Out:
# (0.6190476190476192, (85, 480))

# %%
model_per_1.fit(final_data, final_target,epochs = 5)
global_pred_nn = model_per_1.predict(data_flat)
koefs = np.arange(0,200, step=1)
f1 = np.zeros(koefs.shape[0])
acc = np.zeros(koefs.shape[0])

for i,koef in enumerate(koefs):
        f1[i], acc[i] = f1_score(global_pred_nn>koef,(target_p==1)), accuracy_score(global_pred_nn>koef,(target_p==1))
print(f1.max(), koefs[f1.argmax()],acc.max(), koefs[acc.argmax()])
plt.figure(figsize=[20,10])
plt.plot(koefs,f1, label="f1")
plt.plot(koefs, acc, label="accuracy")
plt.ylabel('Метрика точности', fontsize=26)
plt.xlabel('пороговый коффициент, выше которого ответ нн считается 1', fontsize=26)
plt.title(name,fontsize=26)
plt.grid()
plt.legend(fontsize=26)
plt.show()
# Out:
# Epoch 1/5
# 85/85 [==============================] - ETA: 0s - loss: 0.090 - 0s 824us/step - loss: 0.0949
# Epoch 2/5
# 85/85 [==============================] - ETA: 0s - loss: 0.125 - ETA: 0s - loss: 0.080 - 0s 2ms/step - loss: 0.0949
# Epoch 3/5
# 85/85 [==============================] - ETA: 0s - loss: 0.007 - 0s 800us/step - loss: 0.0949
# Epoch 4/5
# 85/85 [==============================] - ETA: 0s - loss: 0.126 - 0s 729us/step - loss: 0.0949
# Epoch 5/5
# 85/85 [==============================] - ETA: 0s - loss: 0.126 - 0s 835us/step - loss: 0.0949
# 0.6312684365781711 115 0.9112665684830633 129
